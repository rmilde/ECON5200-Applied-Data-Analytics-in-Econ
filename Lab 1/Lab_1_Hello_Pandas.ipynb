# %% [markdown]
# <a href="https://colab.research.google.com/github/rmilde/ECON5200-Applied-Data-Analytics-in-Econ/blob/main/Lab_1_Hello_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: imports

import pandas as pd
import numpy as np

# %%
# Manual Dictionary Construction
# Data Source: Table 1.4 (Jan 2015)
# INSTRUCTION: Complete the lists inside the brackets below.
# Ensure strings have quotes '' and numbers do not.

data = {
    'Country': ['United States',
                'Argentina',
                'Australia',
                'Brazil',
                'Britain',
                'China',
                'Egypt',
                'Euro area',
                'Hong Kong',
                'Indonesia',
                'Japan',
                'Mexico',
                'Norway',
                'Pakistan'
                'Philippines',
                'Russia',
                'Saudi Arabia',
                'South Africa',
                'South Korea'],
    'iso_a3': [],    # Example: ['USA', 'GBR', 'CHN', 'NOR', 'BRA']
    'local_price': [], # Example: [4.79, 2.89, ...]
    'dollar_ex': []    # Example: [1.0, 0.66, ...]
}

# Convert to DataFrame
df = pd.DataFrame(data)
print(df)

# %%
Country	ISO A3	Local Price	Price in USD	Exchange Rate (dollar_ex)
